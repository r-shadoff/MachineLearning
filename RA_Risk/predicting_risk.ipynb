# %%
import pandas as pd 
import os
from glob import glob
import re 

# Import all control genotypes
folder_path = "/Users/rachel/Desktop/GitRepos/MachineLearning/RA_Risk/Controls"
file_list = glob(os.path.join(folder_path, "*.xls"))
all_dfs = []
for path in file_list:
    df = pd.read_excel(path)
    filename = os.path.basename(path)
    # print(filename)
    match = re.search(r'chr(\d+\d)', filename)
    if match:
        chromosome = match.group(1)
    else:
        chromosome = "X"
    df['chromosome'] = chromosome
    all_dfs.append(df)

CTRL_df = pd.concat(all_dfs, ignore_index=True)

# %%
# Control preprocessing
# CTRL_df["condition"] = "CTRL"
# CTRL_df['MAF'] = CTRL_df.apply(lambda row: min(row['allele_A_freq'], row['allele_B_freq']), axis=1)
CTRL_df = CTRL_df.rename(columns={'allele_A':'allele_A_CTRL', 'allele_B':'allele_B_CTRL'})
CTRL_df.head()

# We need allele counts! 
CTRL_df['allele_A_CTRL_Count'] = (CTRL_df['genotype_AA_count'] * 2) + (CTRL_df['genotype_AB_count'])
CTRL_df['allele_B_CTRL_Count'] = (CTRL_df['genotype_BB_count'] * 2) + (CTRL_df['genotype_AB_count'])

# %%
# Import RA genotypes
RA_df = pd.read_csv("/Users/rachel/Desktop/GitRepos/MachineLearning/RA_Risk/Disease_Genotypes_RA.txt", sep="\t", dtype={'chromosome':str,}, na_values=[".-000"])
print(RA_df.columns)
# Out:
# Index(['dbSNP_rsID', 'allele_A', 'allele_B', 'genotype_AA_count',
#        'genotype_AB_count', 'genotype_BB_count', 'genotype_XX_count',
#        'genotype_AA_freq', 'genotype_AB_freq', 'genotype_BB_freq',
#        'allele_A_freq', 'allele_B_freq', 'allele_of_MAF', 'HWE_p_value',
#        'genotype_suspicious', 'number_of_mapped', 'chromosome',
#        'position_in_chromosome', 'duplicate_SNP', 'perlegen_rsID',
#        'perlegen_allele_1', 'perlegen_allele_2', 'perlegen_chromosome',
#        'perlegen_accession_id', 'perlegen_contig_position', 'perlegen_strand',
#        'perlegen_Assayed_sequence'],
#       dtype='object')

# %%
def complement(nucleotide):
    complement_dict = str.maketrans("ACTG", "TGAC")
    complement = nucleotide.translate(complement_dict)
    return(complement)

# RA preprocessing
RA_df['genotype_suspicious'] = RA_df['genotype_suspicious'].replace('*', 1).fillna(0).astype(int)
# RA_df['MAF'] = RA_df.apply(lambda row: min(row['allele_A_freq'], row['allele_B_freq']), axis=1)
# RA_df['condition'] = "RA"

# Strand mismatch between RA and CTRL samples found
# Computing complement to check for strand orientation mismatch
RA_df['allele_A_comp_RA'] = RA_df['allele_A'].apply(complement)
RA_df['allele_B_comp_RA'] = RA_df['allele_B'].apply(complement)
RA_df = RA_df.rename(columns={'allele_A':'allele_A_RA', 'allele_B':'allele_B_RA'})

# We need allele counts! 
RA_df['allele_A_RA_Count'] = (RA_df['genotype_AA_count'] * 2) + (RA_df['genotype_AB_count'])
RA_df['allele_B_RA_Count'] = (RA_df['genotype_BB_count'] * 2) + (RA_df['genotype_AB_count'])

RA_df.head()
RA_df.columns
# Out:
# /var/folders/2x/jkbf1_7146v0xqx_m99sdm000000gn/T/ipykernel_5682/2555743811.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   RA_df['genotype_suspicious'] = RA_df['genotype_suspicious'].replace('*', 1).fillna(0).astype(int)
# Index(['dbSNP_rsID', 'allele_A_RA', 'allele_B_RA', 'genotype_AA_count',
#        'genotype_AB_count', 'genotype_BB_count', 'genotype_XX_count',
#        'genotype_AA_freq', 'genotype_AB_freq', 'genotype_BB_freq',
#        'allele_A_freq', 'allele_B_freq', 'allele_of_MAF', 'HWE_p_value',
#        'genotype_suspicious', 'number_of_mapped', 'chromosome',
#        'position_in_chromosome', 'duplicate_SNP', 'perlegen_rsID',
#        'perlegen_allele_1', 'perlegen_allele_2', 'perlegen_chromosome',
#        'perlegen_accession_id', 'perlegen_contig_position', 'perlegen_strand',
#        'perlegen_Assayed_sequence', 'allele_A_comp_RA', 'allele_B_comp_RA',
#        'allele_A_RA_Count', 'allele_B_RA_Count'],
#       dtype='object')

# %%
RA_subset = RA_df[['dbSNP_rsID','allele_A_RA', 'allele_B_RA', 'allele_A_comp_RA','allele_B_comp_RA','allele_A_RA_Count','allele_B_RA_Count']]
CTRL_subset = CTRL_df[['dbSNP_rsID','allele_A_CTRL','allele_B_CTRL','allele_A_CTRL_Count','allele_B_CTRL_Count']]
df_clean = pd.merge(RA_subset, CTRL_subset, how="inner", on="dbSNP_rsID")
df_clean.head()

front_cols = ['dbSNP_rsID', 'allele_A_RA', 'allele_B_RA', 'allele_A_comp_RA', 'allele_B_comp_RA', 'allele_A_CTRL', 'allele_B_CTRL']
other_cols = [col for col in df_clean.columns if col not in front_cols]
organized_df = df_clean[front_cols + other_cols]
organized_df.head()
# Out:
#    dbSNP_rsID allele_A_RA allele_B_RA allele_A_comp_RA allele_B_comp_RA  \
# 0         970           A           G                T                C
# 1        2060           G           A                C                T
# 2        2952           T           C                A                G
# 3        3431           C           T                G                A
# 4        3444           C           T                G                A
#
#   allele_A_CTRL allele_B_CTRL  allele_A_RA_Count  allele_B_RA_Count  \
# 0             T             C                309                 79
# 1             A             G                 96                294
# 2             T             C                345                 45
# 3             A             G                285                103
# 4             A             G                352                 38
#
#    allele_A_CTRL_Count  allele_B_CTRL_Count
# 0                 1441                  427
# 1                 1411                  457
# 2                 1614                  254
# 3                  604                 1264
# 4                  131                 1737

# %%
def detect_mistmatch(row):
    disease_A = row['allele_A_RA']
    disease_B = row['allele_B_RA']
    disease_A_rev = row['allele_A_comp_RA']
    disease_B_rev = row['allele_B_comp_RA']
    ctrl_A = row['allele_A_CTRL']
    ctrl_B = row['allele_B_CTRL']
    
    # Case 1: alleles already match
    if disease_A == ctrl_A and disease_B == ctrl_B:
        return pd.Series(["direct"])
    
    # Case 2: alleles are flipped
    elif disease_A == ctrl_B and disease_B == ctrl_A:
        return pd.Series(["flipped"])
    
    # Case 3: Strand mismatch, direct
    elif disease_A_rev == ctrl_A and disease_B_rev == ctrl_B:
        return pd.Series(["rev comp direct"])
    
    # Case 4: Strand mismatch, flipped
    elif disease_A_rev == ctrl_B and disease_B_rev == ctrl_A:
        return pd.Series(["rev comp flipped"])
    
    # Case 5: no match (could be multiallelic, strand error, or data error)
    else:
        return pd.Series(["no match"])
    

df_clean[['match_type']] = (df_clean.apply(detect_mistmatch, axis=1))
#df_aligned = df_clean[df_clean['match_type']!= "no match"]
count = 0
for index, row in df_clean.iterrows(): 
    if row['match_type'] == "no match":
        count += 1
    else:
        pass

# print(count) # no discordant SNPs - all are matched as direct, flipped, or complementary alleles

# %%
df_clean.head()

def harmonize_alleles(df):
    for index, row in df.iterrows():
        match = row['match_type']
        if match == "direct":
            pass
        if match == "flipped":
            df.at[index, 'allele_A_CTRL'], df.at[index, 'allele_B_CTRL'] = row['allele_B_CTRL'], row['allele_A_CTRL']
            df.at[index, 'allele_A_CTRL_Count'], df.at[index, 'allele_B_CTRL_Count'] = row['allele_B_CTRL_Count'], row['allele_A_CTRL_Count']
        elif match == "rev comp direct":
            df.at[index, 'allele_A_CTRL'], df.at[index, "allele_B_CTRL"] = row['allele_A_comp_RA'], row['allele_B_comp_RA']
        elif match == "rev comp flipped":
            df.at[index, 'allele_A_CTRL'], df.at[index, "allele_B_CTRL"] = row['allele_B_comp_RA'], row['allele_A_comp_RA']
            df.at[index, 'allele_A_CTRL_Count'], df.at[index, 'allele_B_CTRL_Count'] = row['allele_B_CTRL_Count'], row['allele_A_CTRL_Count']
        else:
            f"Match type not recognized: {index}, {row}, {match}"
    df['harmonized'] = "Yes"
    return df

df_harmonized = harmonize_alleles(df_clean)
df_harmonized.head()
# Out:
#    dbSNP_rsID allele_A_RA allele_B_RA allele_A_comp_RA allele_B_comp_RA  \
# 0         970           A           G                T                C
# 1        2060           G           A                C                T
# 2        2952           T           C                A                G
# 3        3431           C           T                G                A
# 4        3444           C           T                G                A
#
#    allele_A_RA_Count  allele_B_RA_Count allele_A_CTRL allele_B_CTRL  \
# 0                309                 79             T             C
# 1                 96                294             G             A
# 2                345                 45             T             C
# 3                285                103             A             G
# 4                352                 38             A             G
#
#    allele_A_CTRL_Count  allele_B_CTRL_Count        match_type harmonized
# 0                 1441                  427   rev comp direct        Yes
# 1                  457                 1411           flipped        Yes
# 2                 1614                  254            direct        Yes
# 3                 1264                  604  rev comp flipped        Yes
# 4                 1737                  131  rev comp flipped        Yes

# %%
from scipy.stats import fisher_exact
import statsmodels
from statsmodels.stats.multitest import multipletests

def fisher_test(df):
    results = []
    for index, row in df.iterrows():
        table = [row['allele_A_RA_Count'], row['allele_B_RA_Count']], [row['allele_A_CTRL_Count'], row['allele_B_CTRL_Count']]
        oddr, pval = fisher_exact(table)
        results.append({
            'SNP_rsID': row['dbSNP_rsID'],
            'odds_ratio': oddr,
            'p_value':pval
        })
    fisher_df = pd.DataFrame(results)
    return fisher_df
        
fisher_df = fisher_test(df_harmonized)

# %%
fisher_df.head()
padj = []
for index, row in fisher_df.iterrows():
    p_adj = multipletests(row['p_value'], method='fdr_bh')[1]
    padj.append(p_adj)
fisher_df["p_adj"] = padj
fisher_df.head()
# Annotations for snps with p_adj of 0 
# df_filtered_00['SNP_rsID'] = 'rs' + df_filtered_00['SNP_rsID'].astype(str)
# df_00_sorted = df_filtered_00.sort_values(by='odds_ratio', ascending=False)
# df_00_sorted.head()


idx = df_harmonized[df_harmonized['dbSNP_rsID'] == 11227065].index[0]
print(idx)
df_harmonized.iloc[idx]
# Out:
# 37301
# dbSNP_rsID             11227065
# allele_A_RA                   C
# allele_B_RA                   A
# allele_A_comp_RA              G
# allele_B_comp_RA              T
# allele_A_RA_Count           376
# allele_B_RA_Count            10
# allele_A_CTRL                 C
# allele_B_CTRL                 A
# allele_A_CTRL_Count        1857
# allele_B_CTRL_Count          11
# match_type              flipped
# harmonized                  Yes
# Name: 37301, dtype: object

# %%
from scipy.stats import chi2_contingency

def chi2_test(df):
    results = []
    for index, row in df.iterrows():
        table = [row['allele_A_RA_Count'], row['allele_B_RA_Count']],[row['allele_A_CTRL_Count'], row['allele_B_CTRL_Count']]
        chi2, p, dof, expected = chi2_contingency(table)
        results.append({
            'SNP_rsID': row['dbSNP_rsID'],
            'chi2': chi2,
            'p_value':p,
            'deg_freedom':dof,
            'expected':expected
        })
    chi2_df = pd.DataFrame(results)
    return chi2_df

chi2_df = chi2_test(df_harmonized)

padj = []
for index, row in chi2_df.iterrows():
    p_adj = multipletests(row['p_value'], method='fdr_bh')[1]
    padj.append(p_adj)
chi2_df["p_adj"] = padj
chi2_df.head()
# Out:
#    SNP_rsID      chi2   p_value  deg_freedom  \
# 0       970  1.013008  0.314183            1
# 1      2060  0.000000  1.000000            1
# 2      2952  1.018105  0.312969            1
# 3      3431  4.735934  0.029539            1
# 4      3444  3.091395  0.078707            1
#
#                                             expected                   p_adj
# 0  [[300.9751773049645, 87.02482269503547], [1449...   [0.31418340906441816]
# 1  [[95.51372896368467, 294.4862710363153], [457....                   [1.0]
# 2  [[338.35695305580157, 51.6430469441984], [1620...    [0.3129690377964257]
# 3  [[266.40602836879435, 121.59397163120568], [12...  [0.029538800542831384]
# 4  [[360.81045172719223, 29.189548272807794], [17...   [0.07870732241078082]

# %%
filtered = chi2_df[chi2_df['p_adj']<0.05]
len(filtered)
filtered_test_df = filtered.head(n=40)

# %%
# Converting SNP ids to rs IDs for NCBI search
snp_list = filtered_test_df['SNP_rsID'].astype(str).tolist()
rs_ids = []
for snp in snp_list:
    rs_id = "rs" + snp
    rs_ids.append(rs_id)


# API Calls to retrieve data for each SNP
import requests
import re
import time

# 1. Create batches of 100 
def create_batch(iterable, n=20):
    for i in range(0, len(iterable), n):
        yield iterable[i:i+n]

# Convert rsID to UID
def rs_to_uid(snp_rsID_list):
    db = "snp"
    base = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
    term = " OR ".join(snp_rsID_list)
    parameters = {
        "db":db,
        "term": term,
        "retmode":"xml"
    }
    url = f"{base}esearch.fcgi"
    response = requests.get(url, parameters)
    response.raise_for_status()
    with open("snp_uid.xml", "a") as file:
        file.write(response.text)
  
for chunk in create_batch(rs_ids, n=20):
    uids = rs_to_uid(chunk)
    time.sleep(1)

# %%
from bs4 import BeautifulSoup
import lxml
import re
uid_query_list = []
with open("snp_uid.xml", "r") as file: 
    contents = file.read()
    clean_contents = re.sub(r'<\?xml.*?\?>', "", contents)
    clean_contents = re.sub(r'<!DOCTYPE.*?>', "", clean_contents)
    wrapped_contents = f"<root>{clean_contents}</root>"
    soup = BeautifulSoup(wrapped_contents, features="xml")
    id_list = soup.find_all("Id")
    for id in id_list: 
        uid_query_list.append(id.text)

print(uid_query_list)
# Out:
# ['386605925', '386575067', '386431412', '111190448', '61074242', '60993869', '60931066', '60802411', '60666408', '60501608', '60352433', '60331063', '60030157', '59783138', '58976013', '58870618', '58655838', '58339502', '58159257', '57834999', '2100230641', '2100230631', '2100230624', '2100230612', '386624444', '386623847', '386623308', '386606604', '386606419', '61511205', '61506800', '60996781', '60551916', '60244893', '60071076', '59216045', '58844537', '58697252', '58667553', '58617118']

# %%
def snpdb_call(uid_list):
    """ 
    API call to retrieve data for all SNPs in the given list.
    :param snp_rsID_list: list of all SNPs to query. SNPs must be preceeded by rs (example: rs3431)
    """
    db = "snp"
    base = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"

    # POST request
    post_data = {
        "db": db,
        "id": ",".join(uid_list)
    }

    epost_url = f"{base}epost.fcgi"
    epost = requests.post(epost_url, post_data)


    if epost.status_code != 200:
        raise Exception(f"Epost request failed. Status code: {epost.status_code}")
    
    web_match = re.search(r"<WebEnv>(\S+)</WebEnv>", epost.text)
    web = web_match.group(1) if web_match else None
    if web == None:
        raise Exception("Web value not found.")
    
    key_match = re.search(r"<QueryKey>(\d+)</QueryKey>", epost.text)
    key = key_match.group(1) if key_match else None
    if key == None: 
        raise Exception("Key value not found.")    
    
    efetch_url = f"{base}efetch.fcgi?db={db}&query_key={key}&WebEnv={web}&retmode=xml"
    efetch = requests.get(efetch_url)

    if efetch.status_code != 200:
        raise Exception(f"Efetch request failed. Status code: {efetch.status_code}")
    
    return efetch.text

efetch = snpdb_call(uid_query_list)
print(efetch)
# Out:
# <?xml version="1.0" ?>
# <ExchangeSet xmlns:xsi="https://www.w3.org/2001/XMLSchema-instance" xmlns="https://www.ncbi.nlm.nih.gov/SNP/docsum" xsi:schemaLocation="https://www.ncbi.nlm.nih.gov/SNP/docsum ftp://ftp.ncbi.nlm.nih.gov/snp/specs/docsum_eutils.xsd" ><DocumentSummary uid="386605925"><SNP_ID>69141</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>A=0.476837/2388</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>A=0.470331/3012</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>G=0.442138/1704</FREQ></MAF><MAF><STUDY>Chileans</STUDY><FREQ>G=0.383387/240</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>G=0.459375/2058</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>G=0.275/11</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>A=0.484576/72227</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>G=0.438878/438</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>A=0.427543/891</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>A=0.464931/875</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>G=0.491126/1439</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>A=0.490721/899</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>G=0.491563/3554</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>G=0.436667/262</FREQ></MAF><MAF><STUDY>PAGE_STUDY</STUDY><FREQ>A=0.465597/36636</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>A=0.487805/40</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>A=0.375/81</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>A=0.295567/120</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>A=0.380952/16</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>G=0.472135/36564</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>A=0.481095/127341</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>G=0.43096/1598</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>G=0.350467/75</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>G=0.482662/100522</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>RNF220</NAME><GENE_ID>55182</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,ENSEMBL,HUGCELL_USP,EVA-GONL,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,KWOK,SANFORD_IMAGENETICS,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,PAGE_CC,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:44573532:A:G</SPDI><FXN_CLASS>genic_upstream_transcript_variant,intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.44573533A&gt;G,NC_000001.10:g.45039205A&gt;G|SEQ=[A/G]|LEN=1|GENE=RNF220:55182</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>80</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/07/12 13:54</CREATEDATE><UPDATEDATE>2024/11/02 16:13</UPDATEDATE><SS>75405,352373,353291,357412,633646,919802,923801,925538,1989709,1990362,1990577,1992026,5167460,5345454,5377137,15428551,16441437,19138568,20597396,24240650,66483047,66689128,67515787,67880975,70895300,71489326,75595332,76300769,79238522,81135409,81674013,83361792,84191652,87395758,99204366,108161529,110368756,118655687,122646318,138957986,154391587,154935143,159567197,160824669,163330700,164195681,166446234,172217375,173180667,174165515,198380499,218353483,230511928,238210817,275803707,290815559,481398262,481424773,482403725,485494117,537409522,554052128,647839958,778585223,783192586,784147700,825569040,832452420,833078319,834042367,975093057,1067837467,1290617823,1425788735,1574022114,1584456643,1600032462,1643026495,1712328273,1751921277,1794263353,1918301567,1958267464,1966733178,2019665867,2147677605,2161933565,2624348195,2632507889,2697586988,2754351621,2986704783,3021081841,3023595729,3343426875,3626 ...
# <DocumentSummary uid="386575067"><SNP_ID>284301</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>A=0.178514/894</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>A=0.183479/1175</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>A=0.1178/454</FREQ></MAF><MAF><STUDY>Chileans</STUDY><FREQ>A=0.164537/103</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>A=0.145089/650</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>A=0.1/4</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>A=0.181394/27056</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>A=0.121242/121</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>A=0.193858/404</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>A=0.192593/364</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>A=0.077055/225</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>A=0.080786/148</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>A=0.081006/586</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>A=0.14/84</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>A=0.076923/6</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>A=0.175926/38</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>G=0.424051/67</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>G=0.5/7</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>A=0.056183/4351</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>A=0.175454/46441</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>A=0.127562/473</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>A=0.070093/15</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>A=0.142334/32197</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES/><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,ENSEMBL,HUGCELL_USP,EVA-GONL,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,KWOK,SANFORD_IMAGENETICS,KRGDB,CSHL-HAPMAP,PJP,EVA_UK10K_ALSPAC,SGDP_PRJ,CSHL,ABI,USC_VALOUEV,GRF,BIOINF_KMB_FNS_UNIBA,HGDP,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,EVA_SVP,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,SWEGEN,SC_JCM,KRIBB_YJKIM,PERLEGEN</HANDLE><SPDI>NC_000001.11:10634067:G:A</SPDI><FXN_CLASS/><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.10634068G&gt;A,NC_000001.10:g.10694125G&gt;A,NG_089288.1:g.1135G&gt;A|SEQ=[G/A]|LEN=1</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>79</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/07/12 13:54</CREATEDATE><UPDATEDATE>2024/11/02 15:55</UPDATEDATE><SS>368355,720172,909066,910202,13025366,16407309,17340394,23159054,44026103,65835664,67278621,67680391,68213659,68758392,70757134,71330457,75889230,76431170,81836819,83413255,87217003,110047358,137793860,154240183,159416630,160588000,161155518,163067261,173496658,198010303,218233522,230424647,238139939,290622364,480690327,480705826,481566324,485139989,537136875,553790591,647571297,778881813,783016282,783976392,832273733,832928288,833519118,834342822,974851453,1067666081,1289664843,1573884878,1584209509,1599538919,1642532952,1712310849,1751861097,1793895020,1918050229,2019539390,2094782398,2094952825,2147536337,2160011652,2632476550,2697432536,2710665390,2751573116,2986289251,3023534090,3343315418,3626024901,3630515261,3632880611,3633574417,3634306490,3635268545,3635982686,3637018910,3637737045,3638889817,3639757712,3640013854,3642750937,3643811602,3651377360,3654389421,3686154959,3726786560,3744607472,3745823447,3772109091,3798843939,3826021268,3847324358,3848184230,3893065319,3943812896,3984778258,4016893065,4439078668,6206068783,6282876183,6322741687,6333820102,6350381345,6476201403,8142454446,8241160252,8314592536,8316722316,8442365585,8505765621,8512911823,8624196187,8624916395,8666750074,8799474906,8800318605,8831534012,8848781582,8907026282,8936743235,8983628947</SS><ALLELE>R</ALLELE><SNP_CLASS>snv</SNP_CLASS><CHRPOS>1:10634068</CHRPOS><CHRPOS_PREV_ASSM>1:10694125</CHRPOS_PREV_ASSM><TEXT>MergedRs=284301</TEXT><SNP_ID_SORT>000028 ...
# <DocumentSummary uid="386431412"><SNP_ID>305555</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>T=0.067292/337</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>T=0.066209/424</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>T=0.098858/381</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>T=0.072545/325</FREQ></MAF><MAF><STUDY>GENOGRAPHIC</STUDY><FREQ>T=0.098729/20247</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>T=0.075/3</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>T=0.071869/10721</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>T=0.09519/95</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>T=0.076296/159</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>T=0.077374/132</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>T=0.069966/205</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>T=0.067321/487</FREQ></MAF><MAF><STUDY>MGP</STUDY><FREQ>T=0.102996/55</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>T=0.096667/58</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>T=0.235294/16</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>T=0.12037/26</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>T=0.061151/34</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>T=0.035714/2</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>T=0.046317/3587</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>T=0.071695/18977</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>T=0.108145/401</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>T=0.163462/34</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>T=0.091511/7628</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>CACHD1</NAME><GENE_ID>57685</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,ENSEMBL,HUGCELL_USP,EVA-GONL,GENOGRAPHIC,WI_SSAHASNP,WEILL_CORNELL_DGM,KWOK,EVA_MGP,HUMAN_LONGEVITY,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,SGDP_PRJ,KRGDB,USC_VALOUEV,SYSTEMSBIOZJU,SANFORD_IMAGENETICS,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,JJLAB,GNOMAD,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:64538094:T:C</SPDI><FXN_CLASS>intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.64538095T&gt;C,NC_000001.10:g.65003778T&gt;C|SEQ=[T/C]|LEN=1|GENE=CACHD1:57685</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>79</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/07/12 13:56</CREATEDATE><UPDATEDATE>2024/11/02 16:49</UPDATEDATE><SS>393450,395794,505999,1110110,1110369,1603422,1603597,11358426,13038593,15428176,17357680,20513754,24636482,66533040,66809281,67289055,67692362,68768663,70767633,71342484,75853701,76355340,79157555,83420626,87495091,97943128,106571598,108261455,110553618,118755059,122165547,137976451,138919485,154252595,155094794,159429520,163457684,164433354,171528742,173556737,198546509,205070720,218422534,230561949,238251041,253143710,275852848,284062556,290525320,479977869,482381687,533441189,554189063,648053368,779687549,781116139,825488073,832941131,835161367,975230596,1067941449,1291159868,1425831604,1574108567,1584599069,1600316384,1643310417,1710907881,1712338827,1794473110,1918439278,1966762040,2019735960,2147751977,2163060751,2624381714,2632524820,2697668225,2755898570,2986923624,3023629482,3343485424,3626113802,3630560478,3637761101,3638899453,3639447326,3641593549,3642772824,3646677644,3654993067,3686903208,3727105418,3746287584,3783428033,3789083330,3793956094,3799294995,3825566609,3826206630,3836490485,3841896933,3847335886,3848986800,3894010115,3984801059,4016914395,4452080900,6207553797,6283605167,6322849800,6334109460,6351415514,6487859721,8144248234,8242502198,8314464529,8314621044,8319153525,8443541385,8514893824 ...
# <DocumentSummary uid="111190448"><SNP_ID>323972</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>G=0.384185/1924</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>G=0.37336/2391</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>G=0.47042/1813</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>G=0.352902/1581</FREQ></MAF><MAF><STUDY>GENOGRAPHIC</STUDY><FREQ>G=0.462882/94926</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>G=0.5/20</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>G=0.385736/57443</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>G=0.462926/462</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>G=0.456334/951</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>G=0.383422/717</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>A=0.421107/1233</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>A=0.425764/780</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>A=0.419297/3029</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>G=0.461667/277</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>A=0.285714/8</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>G=0.486111/105</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>G=0.270833/117</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>G=0.229167/11</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>A=0.374884/29013</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>G=0.384045/101653</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>G=0.476268/1766</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>G=0.434579/93</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>G=0.463914/30751</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>LINC01362</NAME><GENE_ID>103283057</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,ENSEMBL,HUGCELL_USP,BCM_SSAHASNP,EVA-GONL,GENOGRAPHIC,WI_SSAHASNP,WEILL_CORNELL_DGM,KWOK,HUMAN_LONGEVITY,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,ABI,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,SANFORD_IMAGENETICS,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,BL,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:83070130:G:A,NC_000001.11:83070130:G:C</SPDI><FXN_CLASS>intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.83070131G&gt;A,NC_000001.11:g.83070131G&gt;C,NC_000001.10:g.83535814G&gt;A,NC_000001.10:g.83535814G&gt;C|SEQ=[G/A/C]|LEN=1|GENE=LINC01362:103283057</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>79</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/07/12 13:57</CREATEDATE><UPDATEDATE>2024/11/02 18:09</UPDATEDATE><SS>414377,471273,1062919,1413434,9881635,11409125,15424747,19153394,20595904,23835339,44040364,66474151,66680872,67293261,67697135,68772218,70771856,71347272,75579519,76284036,77595990,79160363,80164945,83427201,87583699,97952921,102758396,108366692,110735532,118850624,122182245,131818797,138025196,154257334,159433833,163588593,164666278,166770467,171564931,173120310,173578055,198702041,218491838,230612802,238290918,253232657,275903019,284085127,290550875,537169423,554362164,648176183,825490881,832945431,975365644,1068043653,1291669152,1425876237,1574191764,1584739589,1600582942,1643576975,1712348343,1794651534,1918568580,1966794092,2019804949,2147822048,2164130174,2624413766,2697744217,2757362364,2985518172,2987125495,3023665266,3343543783,3626140303,3637768334,3638902881,3639449211,3642779184,3646705740,3655206051,3687151077,3727217153,3746440515,3799446555,3826271420,3836524643,3841931848,3847340100,3849250463,3894301801,3944881523,3984808452,4456690466,6208059861,6283854650,6322889568,6329322669,6334203005,6351748266,6491912086,8144811852,8242940620,8314465613,8319973818,8443937435,8505923781, ...
# <DocumentSummary uid="61074242"><SNP_ID>270716</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>A=0.379792/1902</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>A=0.373673/2393</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>A=0.207836/801</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>A=0.247545/1109</FREQ></MAF><MAF><STUDY>GENOGRAPHIC</STUDY><FREQ>A=0.226165/46381</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>A=0.375/15</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>A=0.280838/41873</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>A=0.201403/201</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>A=0.296065/617</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>A=0.359408/680</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>T=0./0</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>G=0.448144/821</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>G=0.43278/3129</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>A=0.201667/121</FREQ></MAF><MAF><STUDY>PAGE_STUDY</STUDY><FREQ>A=0.377395/29701</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>A=0.069767/6</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>A=0.157407/34</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>A=0.245652/113</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>A=0.1875/9</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>G=0.40468/31340</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>A=0.285341/75527</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>A=0.218716/811</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>G=0.346154/72</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>A=0.224788/46261</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>RNF220</NAME><GENE_ID>55182</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,EVA-GONL,GENOGRAPHIC,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,KWOK,SANFORD_IMAGENETICS,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,ABI,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,PAGE_CC,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,EVA_SVP,GMI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:44589193:A:C,NC_000001.11:44589193:A:G,NC_000001.11:44589193:A:T</SPDI><FXN_CLASS>genic_upstream_transcript_variant,intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.44589194A&gt;C,NC_000001.11:g.44589194A&gt;G,NC_000001.11:g.44589194A&gt;T,NC_000001.10:g.45054866A&gt;C,NC_000001.10:g.45054866A&gt;G,NC_000001.10:g.45054866A&gt;T|SEQ=[A/C/G/T]|LEN=1|GENE=RNF220:55182</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>79</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/07/12 13:54</CREATEDATE><UPDATEDATE>2024/11/02 16:13</UPDATEDATE><SS>352333,357363,547300,923827,925489,1989733,1990533,3639824,19149745,20551716,23153623,41233250,66313273,66679140,67268779,67669075,68764925,70747207,71319064,75557034,75995260,77181476,79144144,83408907,87395844,99204381,108161610,110368846,118655797,122088849,137911165,138957956,154229209,154935282,159405753,160571636,163330772,164195868,166446399,170158246,171349817,173436501,198380656,218353542,230511960,238210849,275803744,290815582,480641078,480656391,481500731,485115572,537118267,554052201,647840117,778876660,783004105,783964513,825474662,832261314,832917452,833508282,834337621,975093151,1067837560,1290618286,1425788769,1574022145,1584456748,1600032702,1643026735,1712328283,1751921285,1794263541,1918301677,1958267475,1966733203,2019665918,2147677656,2161934500,2624348225,2632507904,2697587034,2754352792,2986704983,3021081852,3023595754,3343426915,3626082972,3630544493,3632889285,3633583747,3634321101,3635277667,3635996531,3637028074,3637752522,3638895813,3639445270, ...
# <DocumentSummary uid="60993869"><SNP_ID>523864</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>G=0.135184/677</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>G=0.134447/861</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>G=0.178775/689</FREQ></MAF><MAF><STUDY>Daghestan</STUDY><FREQ>G=0.179329/203</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>G=0.102902/461</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>G=0.1/4</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>G=0.16304/24336</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>G=0.190381/190</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>G=0.149712/312</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>G=0.143386/271</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>T=0./0</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>G=0.082969/152</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>G=0.080177/580</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>G=0.163333/98</FREQ></MAF><MAF><STUDY>PAGE_STUDY</STUDY><FREQ>G=0.143042/11256</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>G=0.428571/6</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>G=0.231481/50</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>G=0.102941/56</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>G=0.089286/5</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>G=0.070567/5465</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>G=0.16644/44055</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>G=0.194444/721</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>G=0.056075/12</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>G=0.183684/37974</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>MIR3659HG</NAME><GENE_ID>105378653</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,BCM_SSAHASNP,EVA-GONL,WI_SSAHASNP,WEILL_CORNELL_DGM,KWOK,HUMAN_LONGEVITY,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,ABI,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,SANFORD_IMAGENETICS,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,SI_EXO,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,PAGE_CC,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:38095295:G:A,NC_000001.11:38095295:G:C,NC_000001.11:38095295:G:T</SPDI><FXN_CLASS>intron_variant,genic_downstream_transcript_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.38095296G&gt;A,NC_000001.11:g.38095296G&gt;C,NC_000001.11:g.38095296G&gt;T,NC_000001.10:g.38560968G&gt;A,NC_000001.10:g.38560968G&gt;C,NC_000001.10:g.38560968G&gt;T,NG_053248.1:g.875G&gt;A,NG_053248.1:g.875G&gt;C,NG_053248.1:g.875G&gt;T|SEQ=[G/A/C/T]|LEN=1|GENE=MIR3659HG:105378653</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>83</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/08/11 14:07</CREATEDATE><UPDATEDATE>2024/11/02 15:56</UPDATEDATE><SS>694256,915888,1383742,1781688,1781921,9857646,11387066,17364832,20611072,43993627,66589451,67413128,67777217,68763757,70843362,71427598,74924281,76885935,77231213,78681401,79207214,83474134,87365153,99200954,106560773,108131329,110311983,118627383,122459107,137890773,138969009,154336883,154885209,159513472,160739567,163285248,164126914,166383116,172019013,173912833,198316915,205155074,218331917,230496163,238197823,253037866,275787529,284034041,290807726,410938582,481137076,481159226,482148490,485363610,537307205,553991783,647778529,778928664,783127476,784084058,825537732,832386333,833024775,834390179,975048821,1067805322,1290443020,1397243217,1425775418,1573995104,1584410290,1599939345,1642933378,1712325052,1751918480,1794195208,1918258529,1958262874,1966723994,2019641992,2094782849,2094957281,2147652844,2161569697,2624336824,2632502432,2697560937,2 ...
# <DocumentSummary uid="60931066"><SNP_ID>479336</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>G=0.394768/1977</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>G=0.401624/2572</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>G=0.242865/936</FREQ></MAF><MAF><STUDY>Daghestan</STUDY><FREQ>G=0.264965/301</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>G=0.265179/1188</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>G=0.3/12</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>G=0.243487/243</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>G=0.395873/825</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>G=0.454017/859</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>G=0.371926/1089</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>G=0.347483/2513</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>G=0.236667/142</FREQ></MAF><MAF><STUDY>PAGE_STUDY</STUDY><FREQ>G=0.440078/34635</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>G=0.333333/10</FREQ></MAF><MAF><STUDY>PRJEB37584</STUDY><FREQ>G=0.357868/282</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>G=0.365741/79</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>T=0.31686/109</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>T=0.433333/13</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>G=0.365497/28299</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>G=0.377139/99825</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>G=0.247033/916</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>G=0.337963/73</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>G=0.270546/47226</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>DNM3</NAME><GENE_ID>26052</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,HUGCELL_USP,BCM_SSAHASNP,EVA-GONL,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,SANFORD_IMAGENETICS,KRGDB,ILLUMINA-UK,DDI,EVA_UK10K_ALSPAC,CSHL,SGDP_PRJ,USC_VALOUEV,GRF,BIOINF_KMB_FNS_UNIBA,HGDP,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,JMKIDD_LAB,SSMP,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,EGCUT_WGS,KHV_HUMAN_GENOMES,EVA,JJLAB,GNOMAD,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,SWEGEN,SC_JCM,KRIBB_YJKIM,PAGE_CC,SYSTEMSBIOZJU</HANDLE><SPDI>NC_000001.11:172230432:T:A,NC_000001.11:172230432:T:G</SPDI><FXN_CLASS>intron_variant,genic_downstream_transcript_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.172230433T&gt;A,NC_000001.11:g.172230433T&gt;G,NC_000001.10:g.172199573T&gt;A,NC_000001.10:g.172199573T&gt;G|SEQ=[T/A/G]|LEN=1|GENE=DNM3:26052</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>83</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/08/11 14:02</CREATEDATE><UPDATEDATE>2024/11/02 18:59</UPDATEDATE><SS>648861,9905944,12997508,66717479,67377699,67757308,70825492,71407544,75666323,79195656,83462637,102796439,108702565,111344431,119090627,122390077,154317892,155925583,159494573,164423362,167281136,171920334,173816242,199246556,218718489,230782382,238419506,276101958,537275184,554849911,648500267,825526174,833005958,975814444,1068366223,1293422215,1397264175,1426019029,1574477474,1585201238,1601479750,1644473783,1712381770,1795274052,1919052106,1946015043,1958332502,2020042061,2148069464,2167541077,2624530365,2632593362,2698048178,2710685921,2762711933,2985531129,2987953796,3021151912,3023780063,3343770904,3625554406,3626240756,3637796224,3638914417,3639455600,3642804407,3644510998,3651488784,3655898069,3688025677,3725080035,3727596375,3744056325,3746960940,3770852372,3799962954,3826491041,3836642691,3842052713,3847354037,3850264342,3895503231,3984467225,3984834014,4472628774,6209801372,6284701210,6329417237,6334563067,6349489801,6353010992,6506106994,6506106995,8147040471,8237276522,8244722473,8244722474,8322834207,8445266156,8518266195,8624221808,8626838775,8674399539,8801369877,8832837182,8847169344,8847563023,8910739016,8938643705,8979295001,8982338855,8996291073</SS><ALLELE>D</ALLELE><SNP_CLASS>snv</SNP ...
# <DocumentSummary uid="60802411"><SNP_ID>322875</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>C=0.317492/1590</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>C=0.3198/2048</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>T=0.486248/1874</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>C=0.452679/2028</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>C=0.5/20</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>C=0.390184/58121</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>T=0.49499/494</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>C=0.323727/674</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>C=0.309197/585</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>C=0.204096/598</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>C=0.203057/372</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>C=0.210227/1517</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>C=0.473333/284</FREQ></MAF><MAF><STUDY>PAGE_STUDY</STUDY><FREQ>C=0.299515/23570</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>C=0.388889/14</FREQ></MAF><MAF><STUDY>PRJEB37584</STUDY><FREQ>C=0.173028/136</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>C=0.300926/65</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>C=0.209402/98</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>C=0.173913/8</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>C=0.256542/19822</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>C=0.380135/100618</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>C=0.496224/1840</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>C=0.208333/45</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>C=0.477338/150099</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>LOC107985243</NAME><GENE_ID>107985243</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,EVA-GONL,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,KWOK,SANFORD_IMAGENETICS,KRGDB,PJP,ILLUMINA-UK,DDI,EVA_UK10K_ALSPAC,CSHL,SGDP_PRJ,ABI,USC_VALOUEV,GRF,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,SWEGEN,SC_JCM,KRIBB_YJKIM,PAGE_CC,SYSTEMSBIOZJU,PERLEGEN</HANDLE><SPDI>NC_000001.11:199133481:C:A,NC_000001.11:199133481:C:T</SPDI><FXN_CLASS>intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.199133482C&gt;A,NC_000001.11:g.199133482C&gt;T,NC_000001.10:g.199102610C&gt;A,NC_000001.10:g.199102610C&gt;T|SEQ=[C/A/T]|LEN=1|GENE=LOC107985243:107985243</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>79</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/07/12 13:57</CREATEDATE><UPDATEDATE>2024/10/30 19:06</UPDATEDATE><SS>412944,573636,1119566,2306041,5615476,24279538,44028562,67293172,67697024,68218703,70771765,71347159,75559523,80716146,83426856,83577196,85802577,87929902,106623310,108850398,111609878,119168477,138133723,154257250,156137834,159433759,160616959,164873512,165662850,167416584,173577611,199461294,205065604,218817856,230853316,238474803,253737004,276169339,290709343,480770387,480786175,481682402,485179915,537169213,555029521,648616741,778890076,783036128,783995629,832293796,832945357,834351175,976012734,1068507093,1294162673,1426074724,1574596638,1585407570,1601875295,1644869328,1712394624,1751890394,1795548284,1919242600,1946019149,1958345025,2020140060,2148166606,2169100012,2624577477,2632613040,2698156479,2710689811,2764842299,2984889711,2985534416,2988247996,3021166747,3023829646,3343854152,3625558330,3626278206,3630643697,3632920646,3633616417,3634365716,3635309627,3636044892,3637060152,3637805946,3638918602,3639771167,3640073070,3640990456,3641284547,3642813246,3643824396,3644515140,3651508952,3653659309,3656207966,3688384884,3725093518,3727753025,3744058670,3744666570,3747183415,3770862488,37 ...
# <DocumentSummary uid="60666408"><SNP_ID>3431</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>T=0.2388179/1196</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>T=0.2378201/1523</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>T=0.229891/886</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>T=0.3006696/1347</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>T=0.375/15</FREQ></MAF><MAF><STUDY>GnomAD_exomes</STUDY><FREQ>T=0.2404487/299903</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>T=0.2222625/33122</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>T=0.2645291/264</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>T=0.2723343/567</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>T=0.2206349/417</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>T=0.3549488/1040</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>T=0.3482533/638</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>T=0.3586836/2594</FREQ></MAF><MAF><STUDY>MGP</STUDY><FREQ>T=0.2303371/123</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>T=0.2183333/131</FREQ></MAF><MAF><STUDY>PAGE_STUDY</STUDY><FREQ>T=0.2222834/17359</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>T=0.1081081/8</FREQ></MAF><MAF><STUDY>PRJEB37584</STUDY><FREQ>T=0.3439086/271</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>T=0.2685185/58</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>C=0.3778626/99</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>C=0.4615385/12</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>T=0.2854265/22104</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>T=0.225596/59713</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>T=0.223301/828</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>T=0.3571429/75</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>T=0.2398252/58349</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>MIR9-1HG</NAME><GENE_ID>10485</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,LEE,ENSEMBL,HUGCELL_USP,CGAP-GAI,EVA-GONL,LNCC-LABINFO,WI_SSAHASNP,WEILL_CORNELL_DGM,EVA_MGP,HUMAN_LONGEVITY,KRGDB,PJP,DDI,EVA_UK10K_ALSPAC,SGDP_PRJ,CSHL,SANFORD_IMAGENETICS,USC_VALOUEV,GRF,GENOMED,FSA-LAB,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,WIAF,BCMHGSC_JDW,EVA,JJLAB,GNOMAD,EVA_SVP,GMI,BGI,OMUKHERJEE_ADBS,YEGNASUBRAMANIAN_LAB,TISHKOFF,1000G_HIGH_COVERAGE,EVA_GENOME_DK,ILLUMINA,SWEGEN,KRIBB_YJKIM,PAGE_CC,SYSTEMSBIOZJU,PERLEGEN</HANDLE><SPDI>NC_000001.11:156404463:C:T</SPDI><FXN_CLASS>non_coding_transcript_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.156404464C&gt;T,NC_000001.10:g.156374256C&gt;T,NR_135268.3:n.1071G&gt;A,NR_135268.2:n.1074G&gt;A,NR_135268.1:n.1068G&gt;A,NM_006365.3:c.*90G&gt;A,NR_135267.3:n.453G&gt;A,NR_135267.2:n.456G&gt;A,NR_135267.1:n.450G&gt;A,NR_135266.3:n.426G&gt;A,NR_135266.2:n.429G&gt;A,NR_135266.1:n.423G&gt;A,NR_135265.3:n.353G&gt;A,NR_135265.2:n.356G&gt;A,NR_135265.1:n.350G&gt;A,NM_006365.2:c.*90G&gt;A,NM_001320454.2:c.*62G&gt;A,NM_001320455.2:c.*73G&gt;A,NR_135264.1:n.738G&gt;A,NR_168070.1:n.712G&gt;A,NM_006365.1:c.*90G&gt;A,NR_135263.1:n.620G&gt;A,NM_001320454.1:c.*62G&gt;A,NR_168072.1:n.587G&gt;A,NM_001320453.1:c.*90G&gt;A,NR_135261.1:n.571G&gt;A,NM_001320455.1:c.*73G&gt;A,NR_168073.1:n.538G&gt;A,NR_135260.1:n.486G&gt;A,NR_168071.1:n.460G&gt;A,NR_135262.1:n.386G&gt;A|SEQ=[C/T]|LEN=1|GENE=MIR9-1HG:10485</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>36</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/09/19 17:02</CREATEDATE><UPDATEDATE>2024/11/02 18:30</UPDATEDATE><SS>3466,14041,1539211,4426698,11402002,15433489,16249707,16263278,23839988,65742365,66778694,67295087,67699240,70773700,71349395,75760680,79161600,83345918,87827373,102786480,111168824,122189550,138084874,154259426,159435905,160621104,164141122,171580542,173587589,199098207,205083306,218655407,230735015,238382015 ...
# <DocumentSummary uid="60501608"><SNP_ID>507603</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>A=0.215655/1080</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>A=0.219082/1403</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>A=0.164245/633</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>A=0.139732/626</FREQ></MAF><MAF><STUDY>GENOGRAPHIC</STUDY><FREQ>A=0.162432/33311</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>A=0.225/9</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>A=0.204607/30518</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>A=0.141283/141</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>A=0.174184/363</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>A=0.236982/446</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>A=0.232765/682</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>A=0.248362/455</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>A=0.241084/1744</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>A=0.171667/103</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>A=0.179487/14</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>A=0.138889/30</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>A=0.146067/78</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>A=0.203704/11</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>A=0.247075/19134</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>A=0.209668/55497</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>A=0.162621/603</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>A=0.235849/50</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>A=0.161856/16644</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>LOC101928933</NAME><GENE_ID>101928933</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,EVA-GONL,GENOGRAPHIC,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,SANFORD_IMAGENETICS,KRGDB,PJP,ILLUMINA-UK,DDI,EVA_UK10K_ALSPAC,CSHL,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:179927934:A:C,NC_000001.11:179927934:A:G</SPDI><FXN_CLASS>intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.179927935A&gt;C,NC_000001.11:g.179927935A&gt;G,NC_000001.10:g.179897070A&gt;C,NC_000001.10:g.179897070A&gt;G|SEQ=[A/C/G]|LEN=1|GENE=LOC101928933:101928933</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>83</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/08/11 14:05</CREATEDATE><UPDATEDATE>2024/11/02 19:28</UPDATEDATE><SS>677682,2610625,20477806,23687677,65981824,66234369,66685821,67411134,67776068,68785921,70842353,71426438,75584026,76380125,79206526,82721727,83469879,85407806,87885397,97986528,106614202,108739328,111414352,119112534,122455008,138112321,139153190,154335804,155980913,159512402,164540367,165498273,167325712,172013182,173908884,199303992,205164318,218744298,230801076,238433612,253640008,276119474,284183541,290673357,479544186,482155826,533076796,554904083,648531229,779606483,781007882,825537044,833023706,833614534,835078597,975866396,1068403704,1293627098,1426033272,1574509831,1585256070,1601589190,1644583223,1712385449,1795341824,1919103599,1966909685,2020067714,2148095438,2167974160,2624542514,2632599008,2635004904,2698076972,2710686746,2763304603,2988034302,3023793440,3343793391,3626251775,3630630433,3637799241,3638915629,3639456257,3641626341,3642807219,3646829685,3655982494,3688123662,3727638271,3747022649,3783617672,3789241014,3794113138,3800023281,3826515352,3836654333,3842064536,3847355464,3850367130,3895622632,3945998062,3984836946,4016948670,4474493535,6210004934,6284801768,6323051775,6334600251,6353147442,6507736143,814 ...
# <DocumentSummary uid="60352433"><SNP_ID>486753</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>T=0.359225/1799</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>T=0.349157/2236</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>T=0.157499/607</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>T=0.175446/786</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>T=0.025/1</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>T=0.140281/140</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>T=0.369002/769</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>T=0.301907/570</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>C=0.466894/1368</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>C=0.463428/849</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>C=0.45589/3297</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>T=0.183333/110</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>T=0.028571/2</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>T=0.143519/31</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>T=0.255507/116</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>T=0.192308/10</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>T=0.477364/36968</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>T=0.248419/65754</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>T=0.154261/572</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>C=0.438679/93</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>G=0./0</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>PLXNA2</NAME><GENE_ID>5362</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,SC_SNP,ENSEMBL,HUGCELL_USP,EVA-GONL,WI_SSAHASNP,WEILL_CORNELL_DGM,KWOK,HUMAN_LONGEVITY,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,ABI,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,SANFORD_IMAGENETICS,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:208155403:T:A,NC_000001.11:208155403:T:C,NC_000001.11:208155403:T:G</SPDI><FXN_CLASS>intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.208155404T&gt;A,NC_000001.11:g.208155404T&gt;C,NC_000001.11:g.208155404T&gt;G,NC_000001.10:g.208328749T&gt;A,NC_000001.10:g.208328749T&gt;C,NC_000001.10:g.208328749T&gt;G|SEQ=[T/A/C/G]|LEN=1|GENE=PLXNA2:5362</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>83</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/08/11 14:02</CREATEDATE><UPDATEDATE>2024/11/02 20:00</UPDATEDATE><SS>656421,1187460,1899122,11431516,13023747,16394692,20528734,24142051,44074961,66057835,68790918,70831748,71414471,75545905,75972157,78701691,79199748,81423342,84605556,87950798,98000045,102816673,108901333,111688529,119188015,122414531,138144097,139087063,154324447,159501023,160721623,165011246,165735613,167463174,169859472,171954509,173851303,199537171,205344613,218849750,230876947,238494076,253784005,276193389,284217960,290721867,481079793,481101723,482094666,485335027,537286133,555097453,648657827,778550639,783113282,784070226,825530266,832371971,833012382,834007367,976078749,1068552838,1294406856,1426093236,1574635558,1585474085,1602008218,1645002251,1712399988,1751895132,1795643805,1919305601,1966957579,2020173577,2148203323,2169585551,2624595488,2632621537,2698195319,2765537118,2985536975,2988350983,3023846769,3343883303,3626294433,3630651752,3632923219,3633619170,3634369976,3635312320,3636048738,3637062854,3637810352,3640077330,3640991215,3641285313,3642817038,3646873681,3656308107,3688510963,3727808580,3744670808,3747259326,3772171759,3783671883,3789286744,3794159014,3800265641,3826611898,3836706544,3842117984,3847361318,3850772773,3896074717,3946374521,3984847856,448 ...
# ...
# <DocumentSummary uid="58697252"><SNP_ID>954206</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>T=0.265775/1331</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>T=0.251249/1609</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>T=0.270887/1044</FREQ></MAF><MAF><STUDY>Daghestan</STUDY><FREQ>T=0.285844/315</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>T=0.329688/1477</FREQ></MAF><MAF><STUDY>GENOGRAPHIC</STUDY><FREQ>T=0.285255/58499</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>T=0.4/16</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>T=0.305611/305</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>T=0.294626/614</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>T=0.245223/462</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>C=0.49215/1442</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>T=0.495162/3582</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>T=0.298333/179</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>T=0.214286/12</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>T=0.361111/78</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>C=0.381944/110</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>C=0.325/13</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>C=0.496449/38446</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>T=0.227829/60304</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>T=0.276699/1026</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>T=0.481308/103</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>T=0.273493/47607</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>PM20D1</NAME><GENE_ID>148811</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,EVA-GONL,GENOGRAPHIC,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,SANFORD_IMAGENETICS,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,SGDP_PRJ,USC_VALOUEV,SYSTEMSBIOZJU,GRF,BIOINF_KMB_FNS_UNIBA,HGDP,YY_MCH,ACPOP,KOGIC,1000GENOMES,TOMMO_GENOMICS,JMKIDD_LAB,SSMP,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,EGCUT_WGS,KHV_HUMAN_GENOMES,EVA,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:205838375:C:G,NC_000001.11:205838375:C:T</SPDI><FXN_CLASS>intron_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.205838376C&gt;G,NC_000001.11:g.205838376C&gt;T,NC_000001.10:g.205807504C&gt;G,NC_000001.10:g.205807504C&gt;T|SEQ=[C/G/T]|LEN=1|GENE=PM20D1:148811</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>86</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/10/05 19:10</CREATEDATE><UPDATEDATE>2024/11/02 19:58</UPDATEDATE><SS>1398811,19854847,20482519,24160473,66695499,67928841,68049662,71614331,75575002,79299471,83630014,98270392,99281099,102815748,119183316,123010433,131738157,154499957,156198687,159673801,160997209,172478295,174863316,218842612,230871835,238490202,276188140,290719061,481962235,482919939,537609600,555081503,648648531,825629989,832586624,833184523,833775351,976064462,1068542948,1294349848,1397269938,1426089322,1574626208,1585459644,1601977794,1644971827,1712398860,1751893964,1919290694,2020166338,2148196043,2169476054,2624592091,2632619654,2635006342,2698186616,2765369342,2988326750,3023843316,3343876982,3626290501,3632922656,3633618573,3634368941,3635311738,3636047873,3637062268,3637809201,3638920155,3639458772,3640076295,3640991017,3641285113,3642816174,3646870400,3656287092,3688482413,3727796334,3744669776,3747242382,3772170740,3800248954,3826605687,3836703386,3842114648,3847360883,3850742610,3896040484,3984846921,4480927310,6210722935,6285169626,6329471197,6334735732,6353631763,6513448101,6513448102,8148093361,8245534549,8314470791,8314676533,8324310725,8445999475,8506162404,8519498102,8627299022,8675755776,8799509312,8801571988,8833157354,8849252630,8911671746,8939130503,8998556950</SS><ALLELE>B</ALLELE><SNP_CLASS>snv</SNP_CLASS><CHRPOS>1:205838376</CHRPOS><CHRPOS_PREV_ASS ...
# <DocumentSummary uid="58667553"><SNP_ID>872850</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>G=0.263379/1319</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>G=0.270612/1733</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>G=0.150234/579</FREQ></MAF><MAF><STUDY>Daghestan</STUDY><FREQ>G=0.162257/184</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>G=0.165625/742</FREQ></MAF><MAF><STUDY>GENOGRAPHIC</STUDY><FREQ>G=0.150135/30789</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>G=0.075/3</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>G=0.251782/37520</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>G=0.148297/148</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>G=0.196257/409</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>G=0.302885/567</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>T=0./0</FREQ></MAF><MAF><STUDY>Korea1K</STUDY><FREQ>G=0.085153/156</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>G=0.093525/676</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>G=0.143333/86</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>G=0.194444/14</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>G=0.259259/56</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>G=0.139313/73</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>G=0.057692/3</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>G=0.124035/9604</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>G=0.257675/68204</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>G=0.142125/527</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>G=0.196262/42</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>G=0.16251/31108</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES/><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,BCM_SSAHASNP,EVA-GONL,GENOGRAPHIC,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,SANFORD_IMAGENETICS,KRGDB,CSHL-HAPMAP,ILLUMINA-UK,PJP,DDI,EVA_UK10K_ALSPAC,CSHL,ABI,SGDP_PRJ,USC_VALOUEV,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,BL,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,BUSHMAN,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,KRIBB_YJKIM,URBANLAB,SYSTEMSBIOZJU,PERLEGEN</HANDLE><SPDI>NC_000001.11:68671288:G:A,NC_000001.11:68671288:G:C,NC_000001.11:68671288:G:T</SPDI><FXN_CLASS/><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.68671289G&gt;A,NC_000001.11:g.68671289G&gt;C,NC_000001.11:g.68671289G&gt;T,NC_000001.10:g.69136972G&gt;A,NC_000001.10:g.69136972G&gt;C,NC_000001.10:g.69136972G&gt;T|SEQ=[G/A/C/T]|LEN=1</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>86</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/10/05 19:10</CREATEDATE><UPDATEDATE>2024/11/02 16:53</UPDATEDATE><SS>1296456,5568846,9814152,17363030,23155906,44008463,66853901,67884134,68023775,70976701,71588404,75910372,79285454,83586727,87518311,99215991,106573866,108286112,110597809,118778817,122926620,137990300,154475842,155138222,159650305,160960508,163486228,164494204,166664219,172415660,174758474,198583162,205118938,218438194,230573637,238260403,253163488,275864627,284067068,290531331,481817334,481849868,482810331,485703307,537568133,554219433,648097715,779001367,783297229,784249666,825615972,832558549,833161118,834463731,975260040,1067963986,1291271583,1397248938,1425841898,1574128630,1584630172,1600376519,1643370552,1712341321,1751930900,1794513715,1918467807,1966769803,2019751369,2094783405,2094962178,2147767678,2163294489,2624389238,2632528604,2697685888,2756216596,2986968035,3023637741,3343498652,3626120429,3630564118,3632895440,3633590174,3634329605,3635283953,3636006115,3637034383,3637762937,3638900447,3639447855,3640036966,3642774473,3646684083,3651424957,3655039595,3686958739,3727130739,3744630589,3746321418,3772131899,3783436865,3789090985,3793963727,3799328175,3826221380,3836498101,3841904719,3847337071,3849045 ...
# <DocumentSummary uid="58617118"><SNP_ID>636154</SNP_ID><ALLELE_ORIGIN/><GLOBAL_MAFS><MAF><STUDY>1000Genomes</STUDY><FREQ>T=0.471446/2361</FREQ></MAF><MAF><STUDY>1000Genomes_30X</STUDY><FREQ>T=0.472049/3023</FREQ></MAF><MAF><STUDY>ALSPAC</STUDY><FREQ>T=0.425272/1639</FREQ></MAF><MAF><STUDY>Daghestan</STUDY><FREQ>T=0.436508/495</FREQ></MAF><MAF><STUDY>Estonian</STUDY><FREQ>T=0.369196/1654</FREQ></MAF><MAF><STUDY>GENOME_DK</STUDY><FREQ>T=0.3/12</FREQ></MAF><MAF><STUDY>GnomAD_genomes</STUDY><FREQ>T=0.469224/69904</FREQ></MAF><MAF><STUDY>GoNL</STUDY><FREQ>T=0.442886/442</FREQ></MAF><MAF><STUDY>HGDP_Stanford</STUDY><FREQ>T=0.441939/921</FREQ></MAF><MAF><STUDY>HapMap</STUDY><FREQ>C=0.487831/922</FREQ></MAF><MAF><STUDY>KOREAN</STUDY><FREQ>T=0.433447/1270</FREQ></MAF><MAF><STUDY>Korea4K</STUDY><FREQ>T=0.432799/3130</FREQ></MAF><MAF><STUDY>NorthernSweden</STUDY><FREQ>T=0.381667/229</FREQ></MAF><MAF><STUDY>PRJEB36033</STUDY><FREQ>T=0.384615/10</FREQ></MAF><MAF><STUDY>Qatari</STUDY><FREQ>C=0.467593/101</FREQ></MAF><MAF><STUDY>SGDP_PRJ</STUDY><FREQ>T=0.302752/132</FREQ></MAF><MAF><STUDY>Siberian</STUDY><FREQ>T=0.2/10</FREQ></MAF><MAF><STUDY>TOMMO</STUDY><FREQ>C=0.484487/37476</FREQ></MAF><MAF><STUDY>TOPMED</STUDY><FREQ>T=0.485866/128604</FREQ></MAF><MAF><STUDY>TWINSUK</STUDY><FREQ>T=0.429881/1594</FREQ></MAF><MAF><STUDY>Vietnamese</STUDY><FREQ>T=0.240741/52</FREQ></MAF><MAF><STUDY>ALFA</STUDY><FREQ>T=0.443099/48203</FREQ></MAF></GLOBAL_MAFS><GLOBAL_POPULATION/><GLOBAL_SAMPLESIZE>0</GLOBAL_SAMPLESIZE><SUSPECTED/><CLINICAL_SIGNIFICANCE/><GENES><GENE_E><NAME>LINC02778</NAME><GENE_ID>105378760</GENE_ID></GENE_E></GENES><ACC>NC_000001.11</ACC><CHR>1</CHR><HANDLE>EVA_DECODE,ENSEMBL,HUGCELL_USP,EVA-GONL,WEILL_CORNELL_DGM,HUMAN_LONGEVITY,KWOK,SANFORD_IMAGENETICS,KRGDB,PJP,DDI,EVA_UK10K_ALSPAC,SGDP_PRJ,CSHL,ABI,USC_VALOUEV,SYSTEMSBIOZJU,GRF,GENOMED,BIOINF_KMB_FNS_UNIBA,HGDP,PACBIO,YY_MCH,ACPOP,KOGIC,COMPLETE_GENOMICS,1000GENOMES,TOMMO_GENOMICS,SSMP,JMKIDD_LAB,EVA_UK10K_TWINSUK,TOPMED,HAMMER_LAB,BCM-HGSC-SUB,EGCUT_WGS,KHV_HUMAN_GENOMES,BCMHGSC_JDW,EVA,HGSV,JJLAB,GNOMAD,TSC-CSHL,EVA_SVP,GMI,BGI,YEGNASUBRAMANIAN_LAB,1000G_HIGH_COVERAGE,TISHKOFF,AFFY,EVA_GENOME_DK,ILLUMINA,HUMANGENOME_JCVI,SWEGEN,SC_JCM,KRIBB_YJKIM,URBANLAB,SSAHASNP,PERLEGEN</HANDLE><SPDI>NC_000001.11:60113101:T:C,NC_000001.11:60113101:T:G</SPDI><FXN_CLASS>upstream_transcript_variant,2KB_upstream_variant</FXN_CLASS><VALIDATED>by-frequency,by-alfa,by-cluster</VALIDATED><DOCSUM>HGVS=NC_000001.11:g.60113102T&gt;C,NC_000001.11:g.60113102T&gt;G,NC_000001.10:g.60578774T&gt;C,NC_000001.10:g.60578774T&gt;G|SEQ=[T/C/G]|LEN=1|GENE=LINC02778:105378760</DOCSUM><TAX_ID>9606</TAX_ID><ORIG_BUILD>83</ORIG_BUILD><UPD_BUILD>157</UPD_BUILD><CREATEDATE>2000/08/11 14:18</CREATEDATE><UPDATEDATE>2024/11/02 16:43</UPDATEDATE><SS>808845,1709201,2292286,20529446,24607740,43980121,65979590,66654738,67450065,67801639,70862138,71449583,75505601,78032304,79218978,83503961,87469442,97940683,106569194,108235663,122529343,137959913,138928812,154357190,155051792,159533451,160770627,164372275,166580394,172114157,173994120,205051284,218406198,230549930,238241779,275841293,284057083,290518966,482241760,537345266,554153661,648004053,825549496,833044687,975198861,1067916627,1291040060,1397246703,1425820954,1574085958,1584566349,1600253472,1643247505,1712336309,1794425055,1918406910,1966754336,2019719794,2147735163,2162808962,2624373640,2697649923,2755555965,2984860871,2986874781,3023620694,3343470975,3626106698,3636002114,3637759266,3638898485,3639446758,3640981435,3641275385,3642771175,3646670703,3653633506,3654942150,3686842913,3727078573,3746251333,3783418824,3789075542,3793948242,3799258650,3826190405,3836482581,3841888800,3847334709,3848922721,3893939162,3984798931,4016912647,4451019764,6207434745,6283545182,6322841282,6329285225,6334086157,6351334321,6486916682,8144110745,8242395766,8318960102,8443444377,8505863419,8514735433,8625602187,8668928563,8800628337,8832007978,8848921302,8908407981,8937437692,8979960693,89873 ...
# </ExchangeSet>
